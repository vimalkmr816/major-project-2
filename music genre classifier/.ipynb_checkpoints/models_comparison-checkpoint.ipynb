# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('Data/features_30_sec.csv')
df.head()
# Out:
#           filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1  blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2  blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3  blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4  blues.00004.wav  661794          0.308526         0.087841  0.091529
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.002827             1784.165850          129774.064525
# 1  0.002373             1530.176679          375850.073649
# 2  0.002746             1552.811865          156467.643368
# 3  0.006346             1070.106615          184355.942417
# 4  0.002303             1835.004266          343399.939274
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              2002.449060            85882.761315  ...   52.420910
# 1              2039.036516           213843.755497  ...   55.356403
# 2              1747.702312            76254.192257  ...   40.598766
# 3              1596.412872           166441.494769  ...   44.427753
# 4              1748.172116            88445.209036  ...   86.099236
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0    -1.690215   36.524071    -0.408979   41.597103    -2.303523   55.062923
# 1    -0.731125   60.314529     0.295073   48.120598    -0.283518   51.106190
# 2    -7.729093   47.639427    -1.816407   52.382141    -3.439720   46.639660
# 3    -3.319597   50.206673     0.636965   37.319130    -0.619121   37.259739
# 4    -5.454034   75.269707    -0.916874   53.613918    -4.404827   62.910812
#
#    mfcc20_mean  mfcc20_var  label
# 0     1.221291   46.936035  blues
# 1     0.531217   45.786282  blues
# 2    -2.231258   30.573025  blues
# 3    -3.407448   31.949339  blues
# 4   -11.703234   55.195160  blues
#
# [5 rows x 60 columns]

# %% [markdown]
# ### Preprocessing

# %%
df['label'].unique()
# Out:
# array(['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz',
#        'metal', 'pop', 'reggae', 'rock'], dtype=object)

# %%
# creating a list of labels
df['label']=df['label'].astype('category')
# creating a list of index
df['class_label'] = df['label'].cat.codes

# %%
# creating a json type object dictionary to store labels
genre_dict = dict(zip(df.class_label.unique(), df.label.unique()))   
print(genre_dict[0])
# Out:
# blues

# %%
df['label'].unique()
# Out:
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
# Categories (10, object): ['blues', 'classical', 'country', 'disco', ..., 'metal', 'pop', 'reggae', 'rock']

# %%
# removed the output values from the list
cols = list(df.columns)
cols.remove('label')

# %% [markdown]
# ### Splitting data for training and testing

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
X = df.iloc[:,1:28]
y = df['label']
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=3)

# %% [markdown]
# ### Min-max Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %% [markdown]
# ### Feature importance using Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(random_state = 0, n_jobs = -1).fit(X_train_scaled,y_train)
importances = clf.feature_importances_
#[::x] selects every value at x distance apart
## argsort returns the sorted indexes of the array
indices =  np.argsort(importances)[::-1]
# list of labels of the features
features = [X.columns.values[i] for i in indices]
plt.figure()
plt.title("Feature Importance")
plt.bar(range(X.shape[1]),importances[indices])
plt.xticks(range(X.shape[1]),features,rotation=90)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Feature importance using Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0).fit(X_train_scaled, y_train)
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]
names = [X.columns.values[i] for i in indices]
plt.figure()
plt.title("Feature Importance")
plt.bar(range(X.shape[1]), importances[indices])
plt.xticks(range(X.shape[1]), names, rotation=90)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Fetching file metadata for prediction

# %%
test_df = pd.read_csv('Data/test set.csv')
test_df.head(28)
# Out:
#                                              filename  length  \
# 0                         Automatic_Teller(Metal).wav  661794
# 1                              A_Night_In_Tunisia.wav  661794
# 2                           A_Thousand_Years(Pop).wav  661794
# 3             Beethoven's_5th_Symphony(Classical).wav  661794
# 4           Beethoven_Moonlight_Sonata(Classical).wav  661794
# 5                       Blues_In_My_Bottle(Blues).wav  661794
# 6                  Bullet_For_My_Valentine(Metal).wav  661794
# 7                                    CheapThrills.wav  661794
# 8                                        Daylight.wav  661794
# 9   Franz_Liszt_Hungarian_Rhapsody_no2(Classical).wav  661794
# 10                                     Happy(Pop).wav  661794
# 11                            Heal_The_World(Pop).wav  661794
# 12                              Hold_My_Hand(Pop).wav  661794
# 13              I'l_Play_The_Blues_For_You(Blues).wav  661794
# 14                        I_Want_It_That_Way(Pop).wav  661794
# 15                           Leaving_Trunk(Blues).wav  661794
# 16                  Me_and_the_Devil_Blues(Blues).wav  661794
# 17                    Miles_Davis_All_Blues(Jazz).wav  661794
# 18                      Miles_Davis_So_What(Jazz).wav  661794
# 19                  Mozart_Symphony#40(Classical).wav  661794
# 20                          New_Bomb_Turks(Metal).wav  661794
# 21                              Slow_Blues(Blues).wav  661794
# 22                      Stardust_Trio_Jeepy(Jazz).wav  661794
# 23                        Tears_Don't_Fall(Metal).wav  661794
# 24       The_Dave_Brubeck_Quartet_Take_Five(Jazz).wav  661794
# 25                    The_Girl_From_Ipanema(Jazz).wav  661794
# 26               Titanic_My_Heart_Will_Go_On(Pop).wav  661794
# 27                                  Umbrella(Pop).wav  661794
#
#     chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0           0.472276         0.068043  0.328868  0.000742
# 1           0.389212         0.085853  0.198375  0.006135
# 2           0.305757         0.080404  0.105666  0.000832
# 3           0.264400         0.085957  0.028906  0.000659
# 4           0.183556         0.077236  0.018925  0.000056
# 5           0.342137         0.086963  0.133153  0.002487
# 6           0.502803         0.071302  0.220305  0.002228
# 7           0.432287         0.081026  0.303281  0.003242
# 8           0.361848         0.091339  0.246549  0.009677
# 9           0.255456         0.083324  0.051834  0.001137
# 10          0.385023         0.091006  0.169292  0.003316
# 11          0.334618         0.088657  0.061010  0.000478
# 12          0.363399         0.098932  0.065539  0.001037
fcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  mfcc20_mean  mfcc20_var  \
# 0     -2.266622   21.111026    -6.016707   21.485832     0.404295   20.331105
# 1      0.904816   56.161487    -4.106335   44.813595    -4.778181   68.486442
# 2     -0.506528   35.377095   -10.093406   46.958441    -2.527459   47.267469
# 3      2.410644   64.407690     2.020258   71.699490     3.961606   82.107269
# 4      3.056346   84.860450     1.632566  125.267001     3.197324  155.554954
# 5      2.352099   68.332593    -2.847933   57.514106     1.322084   53.459970
# 6     -0.624401   30.146755    -4.189709   30.667439     1.526623   29.908243
# 7     12.323173  102.643571     4.020115   70.967798     9.927910   99.973350
# 8      9.978457   54.459723     3.008523   56.395135     6.480777   69.093571
# 9     -3.044525   65.671917    -0.586001   75.261912     6.225117  118.340085
# 10     2.391171   59.370466    -1.663073   70.905283     3.928082   98.121520
# 11    -1.847627   60.913134    -7.370114   49.983133     0.274618   94.744350
# 12     3.673110   55.227498    -5.410972   60.179533     6.130406  115.212762
# 13    -0.775869   57.052716    -3.442159   62.195782    -1.321753   44.502845
# 14     1.762526   39.263386    -5.961188   50.561442    -4.495709   37.552003
# 15    -1.186848   60.575149    -6.428458   75.378077    -3.810910   56.067775
# 16    -1.244545   76.777459     4.352349  145.764022     1.997266  153.282617
# 17    -4.793202   65.886404    -2.526114   70.212475     4.992618  111.798180
# 18     1.019880  121.467777     2.545078  148.876718     5.107426  125.158741
# 19     4.923715   49.492163    -3.209916   68.224471    -7.568676  103.403827
# 20    -3.083671   19.926762    -6.214641   27.087218    -0.415265   19.399249
# 21    -0.363703   55.371082    -4.682448   73.918811    -3.798674   60.708163
# 22     2.632993   53.001847    -1.480867   60.427592     2.420122   95.661289
# 23    -5.790789   78.602326    -3.757663   24.742803    -2.088384   62.311504
# 24    -0.281151  131.197056    -3.827563  129.353721     2.630070  142.086809
# 25    -6.127276   54.413231    -5.320178   46.784332    -1.565577   55.121809
# 26    -5.963476  139.704476    -2.628638  120.339960     6.038072   69.918831
# 27     1.868988   55.356046    -1.832418   65.406628     5.773045   89.506425
#
#         label
# 0       metal
# 1        jazz
# 2         pop
# 3   classical
# 4   classical
# 5       blues
# 6       metal
# 7         pop
# 8         pop
# 9   classical
# 10        pop
# 11        pop
# 12        pop
# 13      blues
# 14        pop
# 15      blues
# 16      blues
# 17       jazz
# 18       jazz
# 19  classical
# 20      metal
# 21      blues
# 22       jazz
# 23      metal
# 24       jazz
# 25       jazz
# 26        pop
# 27        pop
#
# [28 rows x 60 columns]

# %% [markdown]
# ### K-nearest neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 13)
knn.fit(X_train_scaled,y_train)
knn.score(X_test_scaled,y_test)
# Out:
# 0.64

# %% [markdown]
# ### Prediction using KNN

# %%
d1 = test_df.iloc[0,:28]
d1 = d1.drop(['filename'])
data1 = scaler.transform([d1])
genre_prediction = knn.predict(data1)
genre_prediction.score()
genre_prediction[0]
# Out:
# 'metal'

# %% [markdown]
# ### Accuracy of  SVM

# %%
from sklearn.svm import SVC
clf = SVC(kernel = 'linear', C=10).fit(X_train_scaled, y_train)
clf.score(X_test_scaled, y_test)
# Out:
# 0.624

# %% [markdown]
# ### Prediction using SVM

# %%
d1 = test_df.iloc[0,:28]
d1 = d1.drop(['filename'])
data1 = scaler.transform([d1])
genre_prediction = clf.predict(data1)
genre_prediction[0]
# Out:
# 'disco'
